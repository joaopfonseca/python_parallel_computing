# %% [markdown]
# # Speed up your Python code
# ## Python is slow
# Compared to low-level languages, Python is typically faster to write, less error prone and easier to debug. However, Python is much harder to optimize — that is, turn into fast machine code — than languages like C or Fortran.
#
# But still, high productivity languages should be chosen over high speed languages for the great majority of scientific computing tasks
#
# This is because
#
# * Of any given program, relatively few lines are ever going to be time-critical
# * For those lines of code that are time-critical, we can achieve C-like speed with minor modifications

# %% [markdown]
# Let's start by trying to understand why high level languages like Python are slower than compiled code
# ### Dynamic typing
# Consider this Python operation

# %%
a, b = 10, 10
a + b
# Out:
# 20

# %% [markdown]
# Even for this simple operation, the Python interpreter has a fair bit of work to do
#
# For example, in the statement `a + b`, the interpreter has to know which operation to invoke
#
# If `a` and `b` are strings, then `a + b` requires string concatenation

# %%
a, b = 'foo', 'bar'
a + b
# Out:
# 'foobar'

# %% [markdown]
# If `a` and `b` are lists, then `a + b` requires list concatenation

# %%
a, b = ['foo'], ['bar']
a + b
# Out:
# ['foo', 'bar']

# %% [markdown]
# We say that the operator `+` is *overloaded* — its action depends on the type of the objects on which it acts.
#
# As a result, Python must check the type of the objects and then call the correct operation which involves substantial overheads
#
# ### Static Types
#
# Compiled languages avoid these overheads with explicit, static types
#
# For example, consider the following C code, which sums the integers from 1 to 10
#
# ```c
# #include <stdio.h>
#
# int main(void) {
#     int i;
#     int sum = 0;
#     for (i = 1; i <= 10; i++) {
#         sum = sum + i;
#     }
#     printf("sum = %d\n", sum);
#     return 0;
# }
# ```
#
# The variables `i` and `sum` are explicitly declared to be integers
#
# Hence, the meaning of addition here is completely unambiguous

# %% [markdown]
# ## Profiling the code
#
# Before we start to refactor our code, or to think about any solutions, it is important to identify where the performance bottlenecks are, so we can make an informed decision regarding the course of action we want to follow.
#
# Profiling involves measuring the resource you want to optimise for, whether it is memory usage or CPU time.
#
# We can use the `time` module to include some timing feature within our code.
#
# Example: Computing the value of $\pi=3.14159\dots$
#
# For $F(x)=\frac{4}{1+x^2}$, the value of $\pi$ can be computed by the numerical integration: $\int_{0}^{1}F(x)dx=\pi$
#
# This can be approximated by: $\sum_{i=0}^{N}F(x_i)\Delta x\approx\pi$

# %%
# compute_pi.py

import time

def Pi(num_steps):
    start = time.time()
    step = 1.0/num_steps
    sum = 0
    
    for i in range(num_steps):
        x= (i+0.5)*step
        sum = sum + 4.0/(1.0+x*x)
    
    pi = step * sum
    end = time.time()
    print("Pi with %d steps is %f in %f secs" %(num_steps, pi, end-start))
    
if __name__ == '__main__':
    Pi(100000)
# Out:
# Pi with 100000 steps is 3.141593 in 0.017568 secs

# %% [markdown]
# ### Time profiling
#
# Time profiling does exactly what it sounds like - it tells you how much time it took to execute a script, which may be a simple one-liner or a whole module.

# %%
# %time Pi(100000)
# Out:
# Pi with 100000 steps is 3.141593 in 0.016338 secs
# CPU times: user 16.4 ms, sys: 1.02 ms, total: 17.4 ms
# Wall time: 16.6 ms

# %% [markdown]
# Use `%timeit` to see how long a script takes to run averaged over multiple runs. The number of runs may be set with with -n 1000, for example, which will limit %timeit to a thousand iterations

# %%
# %timeit Pi(100000)
# Out:
# Pi with 1000 steps is 3.141593 in 0.000158 secs
# Pi with 1000 steps is 3.141593 in 0.000159 secs
# Pi with 1000 steps is 3.141593 in 0.000156 secs
# Pi with 1000 steps is 3.141593 in 0.000155 secs
# Pi with 1000 steps is 3.141593 in 0.000156 secs
# Pi with 1000 steps is 3.141593 in 0.000156 secs
# Pi with 1000 steps is 3.141593 in 0.000155 secs
# Pi with 1000 steps is 3.141593 in 0.000155 secs
# Pi with 1000 steps is 3.141593 in 0.000156 secs
# Pi with 1000 steps is 3.141593 in 0.000172 secs
# Pi with 1000 steps is 3.141593 in 0.
secs
# Pi with 1000 steps is 3.141593 in 0.000155 secs
# Pi with 1000 steps is 3.141593 in 0.000154 secs
# Pi with 1000 steps is 3.141593 in 0.000158 secs
# Pi with 1000 steps is 3.141593 in 0.000220 secs
# Pi with 1000 steps is 3.141593 in 0.000164 secs
# Pi with 1000 steps is 3.141593 in 0.000154 secs
# Pi with 1000 steps is 3.141593 in 0.000153 secs
# Pi with 1000 steps is 3.141593 in 0.000206 secs
# Pi with 1000 steps is 3.141593 in 0.000173 secs
# Pi with 1000 steps is 3.141593 in 0.000191 secs
# Pi with 1000 steps is 3.141593 in 0.000156 secs
# Pi with 1000 steps is 3.141593 in 0.000155 secs
# Pi with 1000 steps is 3.141593 in 0.000154 secs
# Pi with 1000 steps is 3.141593 in 0.000155 secs
# Pi with 1000 steps is 3.141593 in 0.000222 secs
# Pi with 1000 steps is 3.141593 in 0.000172 secs
# Pi with 1000 steps is 3.141593 in 0.000156 secs
# Pi with 1000 steps is 3.141593 in 0.000153 secs
# Pi with 1000 steps is 3.141593 in 0.000153 secs
# Pi with 1000 steps is 3.141593 in 0.000158 secs
# Pi with 1000 steps is 3.141593 in 0.000154 secs
# Pi with 1000 steps is 3.141593 in 0.000154 secs
# Pi with 1000 steps is 3.141593 in 0.000153 secs
# Pi with 1000 steps is 3.141593 in 0.000153 secs
# Pi with 1000 steps is 3.141593 in 0.000154 secs
# Pi with 1000 steps is 3.141593 in 0.000176 secs
# Pi with 1000 steps is 3.141593 in 0.000154 secs
# Pi with 1000 steps is 3.141593 in 0.000156 secs
# Pi with 1000 steps is 3.141593 in 0.000156 secs
# Pi with 1000 steps is 3.141593 in 0.000155 secs
# Pi with 1000 steps is 3.141593 in 0.000154 secs
# Pi with 1000 steps is 3.141593 in 0.000160 secs
# Pi with 1000 steps is 3.141593 in 0.000183 secs
# Pi with 1000 steps is 3.141593 in 0.000181 secs
# Pi with 1000 steps is 3.141593 in 0.000155 secs
# Pi with 1000 steps is 3.141593 in 0.000154 secs
# Pi with 1000 steps is 3.141593 in 0.000154 secs
# Pi with 1000 steps is 3.141593 in 0.000154 secs
# Pi with 1000 steps is 3.141593 in 0.000153 secs
# Pi with 1000 steps is 3.141593 in 0.000155 secs
# Pi with 1000 steps is 3.141593 in 0.000179 secs
# Pi with 1000 steps is 3.141593 in 0.000155 secs
# Pi with 1000 steps is 3.141593 in 0.000156 secs
# Pi with 1000 steps is 3.141593 in 0.000154 secs
# Pi with 1000 steps is 3.141593 in 0.000154 secs
# Pi with 1000 steps is 3.141593 in 0.000153 secs
# Pi with 1000 steps is 3.141593 in 0.000154 secs
# Pi with 1000 steps is 3.141593 in 0.000154 secs
# Pi with 1000 steps is 3.141593 in 0.000153 secs
# Pi with 1000 steps is 3.141593 in 0.000154 secs
# Pi with 1000 steps is 3.141593 in 0.000154 secs
# Pi with 1000 steps is 3.141593 in 0.000155 secs
# Pi with 1000 steps is 3.141593 in 0.000154 secs
# Pi with 1000 steps is 3.141593 in 0.000153 secs
# Pi with 1000 steps is 3.141593 in 0.000180 secs
# Pi with 1000 steps is 3.141593 in 0.000156 secs
# Pi with 1000 steps is 3.141593 in 0.000154 secs
# Pi with 1000 steps is 3.141593 in 0.000154 secs
# Pi with 1000 steps is 3.141593 in 0.000156 secs
# Pi with 1000 steps is 3.141593 in 0.000156 secs
# Pi with 1000 steps is 3.141593 in 0.000156 secs
# Pi with 1000 steps is 3.141593 in 0.000157 secs
# Pi with 1000 steps is 3.141593 in 0.000156 secs
# Pi with 1000 steps is 3.141593 in 0.000200 secs
# Pi with 1000 steps is 3.141593 in 0.000229 secs
# Pi with 1000 steps is 3.141593 in 0.000154 secs
# Pi with 1000 steps is 3.141593 in 0.000179 secs
# Pi with 1000 steps is 3.141593 in 0.000158 secs
# Pi with 1000 steps is 3.141593 in 0.000174 secs
# Pi with 1000 steps is 3.141593 in 0.000164 secs
# Pi with 1000 steps is 3.141593 in 0.000179 secs
# Pi with 1000 steps is 3.141593 in 0.000178 secs
# Pi with 1000 steps is 3.141593 in 0.000251 secs
# Pi with 1000 steps is 3.141593 in 0.000156 secs
# Pi with 1000 steps is 3.141593 in 0.000154 secs
# Pi with 1000 steps is 3.141593 in 0.000157 secs
# Pi with 1000 steps is 3.141593 in 0.000154 secs
# Pi with 1000 steps is 3.141593 in 0.000153 secs
# Pi with 1000 steps is 3.141593 in 0.000154 secs
# Pi with 1000 steps is 3.141593 in 0.000208 secs
# Pi with 1000 steps is 3.141593 in 0.000204 secs
# Pi with 1000 steps is 3.141593 in 0.000156 secs
# Pi with 1000 steps is 3.141593 in 0.000155 secs
# Pi with 1000 steps is 3.141593 in 0.000155 secs
# Pi with 1000 steps is 3.141593 in 0.000154 secs
# Pi with 1000 steps is 3.141593 in 0.000155 secs
# Pi with 1000 steps is 3.141593 in 0.000153 secs
# Pi with 1000 steps is 3.141593 in 0.000153 secs
# Pi with 1000 steps is 3.141593 in 0.000154 secs
# Pi with 1000 steps is 3.141593 in 0.000154 secs
# Pi with 1000 steps is 3.141593 in 0.000154 secs
# Pi with 1000 steps is 3.141593 in 0.000169 secs
# Pi with 1000 steps is 3.141593 in 0.000171 secs
# Pi with 1000 steps is 3.141593 in 0.000153 secs
# Pi with 1000 steps is 3.141593 in 0.000172 secs
# Pi with 1000 steps is 3.141593 in 0.000154 secs
# Pi with 1000 steps is 3.141593 in 0.000153 secs
# Pi with 1000 steps is 3.141593 in 0.000153 secs
# Pi with 1000 steps is 3.141593 in 0.000153 secs
# Pi with 1000 steps is 3.141593 in 0.000154 secs
# Pi with 1000 steps is 3.141593 in 0.000154 secs
# Pi with 1000 steps is 3.141593 in 0.000218 secs
# Pi with 1000 steps is 3.141593 in 0.000156 secs
# Pi with 1000 steps is 3.141593 in 0.000156 secs
# Pi with 1000 steps is 3.141593 in 0.000178 secs
# Pi with 1000 steps is 3.141593 in 0.000154 secs
# Pi with 1000 steps is 3.141593 in 0.000156 secs
# Pi with 1000 steps is 3.141593 in 0.000154 secs
# Pi with 1000 steps is 3.141593 in 0.000154 secs
# Pi with 1000 steps is 3.141593 in 0.000156 secs
# Pi with 1000 steps is 3.141593 in 0.000153 secs
# Pi with 1000 steps is 3.141593 in 0.000154 secs
# Pi with 1000 steps is 3.141593 in 0.000154 secs
# Pi with 1000 steps is 3.141593 in 0.000154 secs
# Pi with 1000 steps is 3.141593 in 0.000176 secs
# Pi with 1000 steps is 3.141593 in 0.000171 secs
# Pi with 1000 steps is 3.141593 in 0.000154 secs
# Pi with 1000 steps is 3.141593 in 0.000154 secs
# Pi with 1000 steps is 3.141593 in 0.000154 secs
# Pi with 1000 steps is 3.141593 in 0.000153 secs
# Pi with 1000 steps is 3.141593 in 0.000153 secs
# Pi with 1000 steps is 3.141593 in 0.000157 secs
# Pi with 1000 steps is 3.141593 in 0.000153 secs
# Pi with 1000 steps is 3.141593 in 0.000153 secs
# Pi with 1000 steps is 3.141593 in 0.000156 secs
# Pi with 1000 steps is 3.141593 in 0.000155 secs
# Pi with 1000 steps is 3.141593 in 0.000154 secs
# Pi with 1000 steps is 3.141593 in 0.000153 secs
# Pi with 1000 steps is 3.141593 in 0.000153 secs
# Pi with 1000 steps is 3.141593 in 0.000153 secs
# Pi with 1000 steps is 3.141593 in 0.000154 secs
# Pi with 1000 steps is 3.141593 in 0.000154 secs
# 464 µs ± 31.5 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %% [markdown]
# If we need a higher level of details, the options we might want to consider is the `line_profiler`.
#
# The `line_profiler` provides a decorator `@profile` that we can use for the functions we want to analyse

# %%
#compute_pi_profiling.py

import time
import line_profiler

@profile
def Pi(num_steps):
    start = time.time()
    step = 1.0 / num_steps
    sum = 0

    for i in range(num_steps):
        x = (i + 0.5) * step
        sum = sum + 4.0 / (1.0 + x * x)

    pi = step * sum
    end = time.time()
    print("Pi with %d steps is %f in %f secs" % (num_steps, pi, end - start))


if __name__ == '__main__':
    Pi(100000)

# %%
# !kernprof -v -l compute_pi_profiling.py
# Out:
# Pi with 100000 steps is 3.141593 in 0.304553 secs
# Wrote profile results to compute_pi_profiling.py.lprof
# Timer unit: 1e-06 s
#
# Total time: 0.16922 s
# File: compute_pi_profiling.py
# Function: Pi at line 4
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      4                                           @profile
#      5                                           def Pi(num_steps):
#      6         1          4.0      4.0      0.0      start = time.time()
#      7         1          2.0      2.0      0.0      step = 1.0 / num_steps
#      8         1          1.0      1.0      0.0      sum = 0
#      9
#     10    100001      51361.0      0.5     30.4      for i in range(num_steps):
#     11    100000      56650.0      0.6     33.5          x = (i + 0.5) * step
#     12    100000      61141.0      0.6     36.1          sum = sum + 4.0 / (1.0 + x * x)
#     13
#     14         1          1.0      1.0      0.0      pi = step * sum
#     15         1          3.0      3.0      0.0      end = time.time()
#     16         1         57.0     57.0      0.0      print("Pi with %d steps is %f in %f secs" % (num_steps, pi, end - start))

# %% [markdown]
# To use the line_profiler extension within Jupyter. This eliminates the need to modify the code with the @profile decorator, and instead you simply load the extension by doing

# %%
# %load_ext line_profiler

# %% [markdown]
# To further understand why this is slow, we can profile the code line by line with `%lprun`, where "lp" stands for "line profiler", and the -f argument specifies the function you'd like to profile

# %%
# %lprun -f Pi Pi(1000000)
# Out:
# Pi with 1000000 steps is 3.141593 in 3.103202 secs

# %% [markdown]
# Another aspect of profiling is the amount of memory an operation uses. This can be evaluated with another IPython extension, the `memory_profiler`.

# %%
# %load_ext memory_profiler

# %% [markdown]
# The memory profiler extension contains two useful magic functions: the `%memit` magic (which offers a memory-measuring equivalent of `%timeit`)

# %%
# %memit Pi(1000000)
# Out:
# Pi with 1000000 steps is 3.141593 in 0.149621 secs
# Pi with 1000000 steps is 3.141593 in 0.158346 secs
# peak memory: 55.21 MiB, increment: 0.05 MiB

# %% [markdown]
# Similarly, to perform line-by-line or memory profiling, we can use the command `%mprun`.
#
# Unfortunately, this magic works only for functions defined in separate modules rather than the notebook itself, so we'll start by using the %%file magic to create a simple module called mprun_demo.py, which contains our sum_of_lists function, with one addition that will make our memory profiling results more clear:

# %%
# %%file Pi.py
import time

def Pi(num_steps):
    start = time.time()
    step = 1.0/num_steps
    sum = 0
    
    for i in range(num_steps):
        x= (i+0.5)*step
        sum = sum + 4.0/(1.0+x*x)
    
    pi = step * sum
    end = time.time()
    print("Pi with %d steps is %f in %f secs" %(num_steps, pi, end-start))
    
if __name__ == '__main__':
    Pi(100000)
# Out:
# Overwriting Pi.py

# %%
from Pi import Pi
# %mprun -f Pi Pi(100000)
# Out:
# Pi with 100000 steps is 3.141593 in 7.671361 secs

# %% [markdown]
# ## Vectorization
#
# When we run batch operations on arrays as batch operators, the result is C or Fortran-like speed, then the code is *vectorized*
#
# **Numpy** is all about vectorization. You'll need to change your way of thinking from procedure to vectors
#
# Many functions provided by NumPy are so-called universal functions — also called [*ufuncs*](https://docs.scipy.org/doc/numpy/reference/ufuncs.html) that operate on ndarrays in an element-by-element fashion.

# %%
import random
import numpy as np
import time

# %%
start = time.time()   # Start timing
n = 100_000
sum = 0
for i in range(n):
    x = random.uniform(0, 1)
    sum += x**2
end = time.time() # End timing

print("The squared sum with %d numbers is %f in %f secs"
     %(n, sum, end-start))
# Out:
# The squared sum with 100000 numbers is 33306.076639 in 0.077598 secs

# %% [markdown]
# Now compare with the vectorized code

# %%
start = time.time()   # Start timing
n = 100_000
x = np.random.uniform(0, 1, n)
np.sum(x**2)
end = time.time() # End timing

print("The squared sum with %d numbers is %f in %f secs"
     %(n, sum, end-start))
# Out:
# The squared sum with 100000 numbers is 33306.076639 in 0.007632 secs

# %% [markdown]
# Consider the problem of maximizing a function $f$ of two variables $(x,y)$ over the square $[-a, a]\times[-a, a]$:
#
# $f(x,y)=\frac{cos(x^2+y^2)}{1+x^2+y^2}$ and $a=3$

# %%
def f(x, y):
    return np.cos(x**2 + y**2) / (1 + x**2 + y**2)

grid = np.linspace(-3, 3, 1000)
m = -np.inf

start = time.time()
for x in grid:
    for y in grid:
        z = f(x, y)
        if z > m:
            m = z

end = time.time()

print("The maximum value is %f in %f secs"
     %(m, end-start))
# Out:
# The maximum value is 0.999982 in 3.093700 secs

# %% [markdown]
# And here’s a vectorized version

# %%
def f(x, y):
    return np.cos(x**2 + y**2) / (1 + x**2 + y**2)

grid = np.linspace(-3, 3, 1000)
x, y = np.meshgrid(grid, grid)

start = time.time()
np.max(f(x, y))
end = time.time()

print("The maximum value is %f in %f secs"
     %(m, end-start))
# Out:
# The maximum value is 0.999982 in 0.057325 secs

# %% [markdown]
# ### Exercise: convert the compute_pi.py with vectorization tricks using numpy. How much can vectorization improve the computation efficiency?

# %% [markdown]
# ## Numba
#
# Numba works by generating optimized machine code using the LLVM compiler infrastructure at import time, runtime, or statically (using the included pycc tool).
#
# With a few annotations, array-oriented and math-heavy Python code can be just-in-time compiled to native machine instructions, similar in performance to C, C++ and Fortran, without having to switch languages or Python interpreters.
#
# ```python
# from numba import jit
# ```
#
# Consider some problems that are difficult to vectorize
#
# We generate the trajectory of a difference equation given an initial condition, and take the difference equation to be the quadratic map: $x_{t+1} = 4x_t(1-x_t)$

# %%
def qm(x0, n):
    x = np.empty(n+1)
    x[0] = x0
    for t in range(n):
        x[t+1] = 4 * x[t] * (1 - x[t])
    return x

start = time.time()
x = qm(0.1, int(10**5))
end = time.time()
time1 = end-start
print("The mean value is %f in %f secs"
     %(np.mean(x), end-start))
# Out:
# The mean value is 0.499034 in 0.087057 secs

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(x[0:100])
plt.xlabel('time')
plt.ylabel('$x_t$')
plt.show()

# %% [markdown]
# Let’s time and compare identical function calls with JIT compilation:

# %%
qm_numba = jit(qm)  # qm_numba is now a 'compiled' version of qm
start = time.time()
qm_numba(0.1, int(10**5))
end = time.time()
print("The mean value is %f in %f secs"
     %(np.mean(x), end-start))
# Out:
# The mean value is 0.499034 in 0.076095 secs

# %% [markdown]
# The first execution is relatively slow because of JIT compilation (see below)
#
# Next time and all subsequent times it runs much faster:

# %%
start = time.time()
qm_numba(0.1, int(10**5))
end = time.time()
time2 = end-start
print("The mean value is %f in %f secs"
     %(np.mean(x), end-start))
# Out:
# The mean value is 0.499034 in 0.000486 secs

# %%
time1 / time2  # Calculate speed gain
# Out:
# 179.07994114762138

# %% [markdown]
# This is a huge progress relative to how simple and clear the implementation is
#
# If you don’t need a separate name for the “numbafied” version of qm, you can just put `@jit` before the function. This is equivalent to `qm = jit(qm)`

# %%
@jit
def qm(x0, n):
    x = np.empty(n+1)
    x[0] = x0
    for t in range(n):
        x[t+1] = 4 * x[t] * (1 - x[t])
    return x

# %% [markdown]
# ### Exercise: implement the "numbafied" version of compute_pi, show how much does improve the computation efficiency?

# %% [markdown]
# ## Numba for vectorization
#
# Numba can also be used to create custom `ufuncs` with the `@vectorize` decorator

# %%
from numba import vectorize

@vectorize
def f_vec(x, y):
    return np.cos(x**2 + y**2) / (1 + x**2 + y**2)

# %%
grid = np.linspace(-3, 3, 1000)
x, y = np.meshgrid(grid, grid)

np.max(f_vec(x, y))  # Run once to compile

start = time.time()
m = np.max(f_vec(x, y))
end = time.time()
print("The maximum value is %f in %f secs"
     %(m, end-start))
# Out:
# The maximum value is 0.999982 in 0.018391 secs

# %% [markdown]
# This is faster than our vectorized version using NumPy’s ufuncs
#
# Why should that be? After all, anything vectorized with NumPy will be running in fast C or Fortran code
#
# The reason is that it’s much less memory intensive
#
# For example, when NumPy computes np.cos($x**2$ + $y**2$) it first creates the intermediate arrays $x**2$ and $y**2$, then it creates the array np.cos($x**2$ + $y**2$)
#
# In our `@vectorize` version using Numba, the entire operator is reduced to a single vectorized process and none of these intermediate arrays are created
#
# We can gain further speed improvements using Numba’s automatic parallelization feature by specifying `target=’parallel’`
#
# In this case, we need to specify the types of our inputs and outputs

# %%
@vectorize('float64(float64, float64)', target='parallel')
def f_vec(x, y):
    return np.cos(x**2 + y**2) / (1 + x**2 + y**2)

# %%
np.max(f_vec(x, y))  # Run once to compile

start = time.time()
m = np.max(f_vec(x, y))
end = time.time()
print("The maximum value is %f in %f secs"
     %(m, end-start))
# Out:
# The maximum value is 0.999982 in 0.008841 secs

# %% [markdown]
# ### Exercise: implement the "numbafied" version of compute_pi with vectorization, compare with the previous impelementations

# %% [markdown]
# ## Cython
#
# Like Numba, Cython provides an approach to generating fast compiled code that can be used from Python. As was the case with Numba, a key problem is the fact that Python is dynamically typed
#
# As you’ll recall, Numba solves this problem (where possible) by inferring type. Cython’s approach is different — programmers add type definitions directly to their “Python” code. As such, the Cython language can be thought of as Python with type definitions
#
# In addition to a language specification, Cython is also a language translator, transforming Cython code into optimized C and C++ code. Cython also takes care of building language extentions — the wrapper code that interfaces between the resulting compiled code and Python

# %% [markdown]
# Suppose that we want to compute the sum $\sum_{n}^{i=0} \alpha^i = \frac{1-\alpha^{n+1}}{1-\alpha}$ for given $\alpha$, $n$ for a geometric progression
#
# Here’s a pure Python function that does the job

# %%
def geo_prog(alpha, n):
    current = 1.0
    sum = current
    for i in range(n):
        current = current * alpha
        sum = sum + current
    return sum

# %% [markdown]
# Here’s a C function that will do the same thing
#
# ```c
# double geo_prog(double alpha, int n) {
#     double current = 1.0;
#     double sum = current;
#     int i;
#     for (i = 1; i <= n; i++) {
#         current = current * alpha;
#         sum = sum + current;
#     }
#     return sum;
# }
# ```

# %% [markdown]
# We’re going to run our Cython code in the Jupyter notebook

# %%
# %load_ext Cython

# %%
# %%cython
# def geo_prog_cython(double alpha, int n):
#     cdef double current = 1.0
#     cdef double sum = current
#     cdef int i
#     for i in range(n):
#         current = current * alpha
#         sum = sum + current
#     return sum

# %% [markdown]
# Here cdef is a Cython keyword indicating a variable declaration, and is followed by a type
#
# The `%%cython` line at the top is not actually Cython code — it’s a Jupyter cell magic indicating the start of Cython code
#
# After executing the cell, you can now call the function ```geo_prog_cython``` from within Python
#
# What you are in fact calling is compiled C code with a Python call interface

# %%
start = time.time()
v = geo_prog(0.99, int(10**6))
end = time.time()
print("The value is %f in %f secs"
     %(v, end-start))
# Out:
# The value is 100.000000 in 0.137585 secs

# %%
start = time.time()
v = geo_prog_cython(0.99, int(10**6))
end = time.time()
print("The value is %f in %f secs"
     %(v, end-start))
# Out:
# The value is 100.000000 in 0.050911 secs

# %% [markdown]
# ### Cython with NumPy arrays
# For problem of generating the iterates of the quadratic map, it iterates and returning a time series requires us to work with arrays.
#
# The natural array type to work with is NumPy arrays.

# %%
# %%cython
# import numpy as np
#
# def qm_cython_first_pass(double x0, int n):
#     cdef int t
#     x = np.zeros(n+1, float)
#     x[0] = x0
#     for t in range(n):
#         x[t+1] = 4.0 * x[t] * (1 - x[t])
#     return np.asarray(x)

# %% [markdown]
# If you run this code and time it, you will see that it’s performance is disappointing — nothing like the speed gain we got from Numba

# %%
start1 = time.time()
qm_cython_first_pass(0.1, int(10**5))
end1 = time.time()
print("The mean value is %f in %f secs"
     %(np.mean(x), end1-start1))

start2 = time.time()
qm_numba(0.1, int(10**5))
end2 = time.time()
print("The mean value is %f in %f secs"
     %(np.mean(x), end2-start2))
# Out:
# The mean value is 0.000000 in 0.043439 secs
# The mean value is 0.000000 in 0.000374 secs

# %% [markdown]
# The reason is that working with NumPy arrays incurs substantial Python overheads
#
# We can do better by using Cython’s typed `memoryviews`, which provide more direct access to arrays in memory
#
# When using them, the first step is to create a NumPy array. Next, we declare a memoryview and bind it to the NumPy array

# %%
# %%cython
# import numpy as np
# from numpy cimport float_t
#
# def qm_cython(double x0, int n):
#     cdef int t
#     x_np_array = np.zeros(n+1, dtype=float)
#     cdef float_t [:] x = x_np_array
#     x[0] = x0
#     for t in range(n):
#         x[t+1] = 4.0 * x[t] * (1 - x[t])
#     return np.asarray(x)

# %% [markdown]
# `cimport` pulls in some compile-time information from NumPy
#
# `cdef float_t [:] x = x_np_array` creates a memoryview on the NumPy array `x_np_array`
#
# the return statement uses `np.asarray(x)` to convert the memoryview back to a NumPy array

# %%
start3 = time.time()
qm_cython(0.1, int(10**5))
end3 = time.time()
print("The mean value is %f in %f secs"
     %(np.mean(x), end3-start3))
# Out:
# The mean value is 0.000000 in 0.000966 secs

# %% [markdown]
# This is fast, although still slightly slower than `qm_numba`

# %%
# %%cython
# cpdef double Pi_cython(int num_steps):
#     cdef double step = 1.0 / num_steps
#     cdef double sum = 0
#
#     for i in range(num_steps):
#         x = (i + 0.5) * step
#         sum = sum + 4.0 / (1.0 + x * x)
#
#     cdef double pi = step * sum
#     return pi

# %%
start = time.time()
num_steps = 100000000
pi = Pi_cython(num_steps)
end = time.time()
print("Pi with %d steps is %f in %f secs" % (num_steps, pi, end - start))
# Out:
# Pi with 100000000 steps is 3.141593 in 8.071239 secs

# %% [markdown]
# ## Python, Cython? (from Scikit-Learn documentation)
#
# When implementing a new algorithm is thus recommended to start implementing it in Python using Numpy and Scipy by taking care of avoiding looping code using the vectorized idioms of those libraries. In practice this means trying to **replace any nested for loops by calls to equivalent Numpy array methods**.
#
# Sometimes however an algorithm cannot be expressed efficiently in simple vectorized Numpy code. In this case, the recommended strategy is the following:
# * **Profile** the Python implementation to find the main bottleneck and isolate it in a dedicated module level function. This function will be reimplemented as a compiled extension module.
# * If there exists a well maintained C/C++ implementation of the same algorithm that is not too big, you can write a **Cython wrapper** for it and include a copy of the source code of the library in the source tree
# * Otherwise, write an optimized version of your Python function using **Cython or Numba** directly.
# * Once the code is optimized (not simple bottleneck spottable by profiling), check whether it is possible to have **coarse grained parallelism** that is amenable to multi-processing
